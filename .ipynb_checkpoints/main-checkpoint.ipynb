# %%
import pandas as pd
import numpy as np
import datetime

music_df = pd.read_json("StreamingHistory0.json")
music_df = music_df.set_index("endTime")
music_df["msPlayed"] = music_df["msPlayed"].astype(np.int)

ser = music_df["msPlayed"]

music_df.drop(music_df[music_df["msPlayed"] <= 30000].index, inplace=True)
music_df.to_csv("help.csv")

dow = []

#Use datetime to get day of the week
#strptime and strftime

def append_day(x, day):
    for i in range(0, x, 1):
        dow.append(day)
'''
append_day(4, "Friday")
append_day(5, "Saturday")
append_day(31, "Sunday")
append_day(21, "Monday")
append_day(63, "Tuesday")
append_day(30, "Wednesday")
append_day(32, "Thursday")
append_day(19, "Friday")
append_day(16, "Saturday")
append_day(8, "Sunday")
append_day(31, "Monday")
append_day(55, "Tuesday")
append_day(11, "Wednesday")
append_day(31, "Thursday")
append_day(15, "Friday")
append_day(33, "Saturday")
append_day(40, "Sunday")
append_day(39, "Monday")
append_day(39, "Tuesday")
append_day(33, "Wednesday")
'''

append_day(1, "Friday")
append_day(1, "Wednesday")
append_day(14, "Monday")
append_day(24, "Tuesday")
append_day(29, "Wednesday")
append_day(31, "Thursday")
append_day(25, "Friday")
append_day(9, "Saturday")
append_day(14, "Sunday")
append_day(11, "Monday")
append_day(23, "Tuesday")
append_day(10, "Wednesday")
append_day(5, "Thursday")
append_day(12, "Friday")
append_day(7, "Sunday")
append_day(9, "Monday")
append_day(26, "Tuesday")
append_day(12, "Wednesday")
append_day(28, "Thursday")
append_day(25, "Friday")
append_day(4, "Saturday")
append_day(24, "Tuesday")
append_day(22, "Wednesday")
append_day(28, "Thursday")
append_day(16, "Friday")
append_day(1, "Saturday")
append_day(6, "Sunday")
append_day(6, "Monday")
append_day(20, "Tuesday")
append_day(36, "Wednesday")
append_day(23, "Thursday")
append_day(14, "Friday")
append_day(21, "Saturday")
append_day(11, "Sunday")
append_day(2, "Monday")
append_day(29, "Tuesday")
append_day(9, "Wednesday")

music_df.insert(3, "Day of the Week", dow)
#music_df.to_csv("help_cleaned.csv")

# %%
import requests
import json

token = "BQDreg8KdOXHiKzA6fyEPmU0gwDIy29dmYarxsutkX7xiph2LQv0Zck-8Zoru7u3BlkaXxul6Qf4Xx6IoNxq0OAwqtY_LuLLDitT5YSmedFzsfKmlpw_7WzAUOEXJT5jcqOl_uLAJAdqvmD_w25bcUwK "
API_endpoint = "https://api.spotify.com/v1/search"


def make_request(fullURL):
    headers = {"Accept": "application/json", "Content-Type": "application/json", "Authorization": "Bearer " + token}

    response = requests.get(url=fullURL, headers=headers)
    json_object = json.loads(response.text)

    return json_object

def search_request(search_term, search_type):
    search_term = requests.utils.quote(search_term)
    search_type = requests.utils.quote(search_type)
    url = API_endpoint + "?q=" + search_term
    url += "&type=" + search_type
    print(url)
    json_obj = make_request(url)
    return json_obj

def get_genres(json_obj):
    artists = json_obj["artists"]
    items = artists["items"]
    first_artist_item = items[0] # TODO: are they sorted by match confidence/popularity?
    genres = first_artist_item["genres"]
    return genres

def main(ser):
    json_obj = search_request(ser[i], "artist")
    genres = get_genres(json_obj)
    genre.append(genres)
    #print(ser, "'s genres:", genres)

def extract(lst):
    return (item[0] for item in lst)

ser1 = music_df["artistName"]
genre = []
for i in range(0, len(ser1), 1):
    main(ser1)
'''
for i in range(0, 184, 1):
    main(ser1)

genre.append("emo")
for i in range(186, 207, 1):
    main(ser1)

genre.append("country pop")
for i in range(209, 225, 1):
    main(ser1)

genre.append("soft rock")
for i in range(227, 269, 1):
    main(ser1)

genre.append("country")
for i in range(271, len(ser1), 1):
    main(ser1)
'''

#genre_df = pd.DataFrame(genre)
#genre_df.to_csv("help.csv")
#print(music_df)
#print(count)
# Out:
# https://api.spotify.com/v1/search?q=blink-182&type=artist
# https://api.spotify.com/v1/search?q=Veronica%20Vega&type=artist
# https://api.spotify.com/v1/search?q=Old%20Dominion&type=artist
# https://api.spotify.com/v1/search?q=Chris%20Young&type=artist
# https://api.spotify.com/v1/search?q=Old%20Dominion&type=artist
# https://api.spotify.com/v1/search?q=Jonas%20Brothers&type=artist
# https://api.spotify.com/v1/search?q=Dan%20%2B%20Shay&type=artist
# https://api.spotify.com/v1/search?q=Jay%20Park&type=artist
# https://api.spotify.com/v1/search?q=Gente%20De%20Zona&type=artist
# https://api.spotify.com/v1/search?q=Panic%21%20At%20The%20Disco&type=artist
# https://api.spotify.com/v1/search?q=Little%20Big%20Town&type=artist
# https://api.spotify.com/v1/search?q=Sam%20Hunt&type=artist
# https://api.spotify.com/v1/search?q=The%20Beatles&type=artist
# https://api.spotify.com/v1/search?q=Florida%20Georgia%20Line&type=artist
# https://api.spotify.com/v1/search?q=Greek%20Fire&type=artist
# ...

# %%
genre1 = []
for item in genre:
    if len(genre[item]) > 0:   
        genre1.append(item[0])

#music_df.insert(3, "Genre", genre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2cc300f353f> in <module>
#       1 genre1 = []
# ----> 2 for item in genre:
#       3     if len(genre[item]) > 0:
#       4         genre1.append(item[0])
#       5
#
# NameError: name 'genre' is not defined

# %%
import matplotlib.pyplot as plt

grouped_by_day = music_df.groupby("Day of the Week")
monday = grouped_by_day.get_group("Monday")
x = monday["Genre"]

def histogram(x, y):
    plt.figure()
    plt.hist(x)
    plt.title(y)
    plt.xlabel("Genres")
    plt.ylabel("Frequency")
    plt.xticks(rotation=90)
    plt.show()
histogram(x, "Monday")

tuesday = grouped_by_day.get_group("Tuesday")
y = tuesday["Genre"]
histogram(y, "Tuesday")

wednesday = grouped_by_day.get_group("Wednesday")
z = wednesday["Genre"]
histogram(z, "Wednesday")

thursday = grouped_by_day.get_group("Thursday")
a = thursday["Genre"]
histogram(a, "Thursday")

friday = grouped_by_day.get_group("Friday")
b = friday["Genre"]
histogram(b, "Friday")

saturday = grouped_by_day.get_group("Saturday")
c = saturday["Genre"]
histogram(c, "Saturday")

sunday = grouped_by_day.get_group("Sunday")
d = sunday["Genre"]
histogram(d, "Sunday")

#Pie chart might also work

# %% [markdown]
# One tailed, two sample inedependent/dependent t-test
# Is mean of certain genre higher in quarantine than normal?
# Is mean of certain genre higher than it was a year ago?
# Significant difference between months?
# Total amount of music between day of the week or month?
# $\alpha = 0.025$
